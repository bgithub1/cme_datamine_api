# %% [markdown]
# ### Read example CME Datamine Top-of-Book records for CLK20 on 2020-03-12.
#
# There are over 85 million rows of bid/ask quote information that occured during this day.  They have been stored in 86 csv files, each having 1 million rows except `df_clk20_tob_85.csv`, which has the remaining rows.

# %%
import pandas as pd

# %%
df_tob_03 = pd.read_csv('../sports_betting_apis/temp_folder/c')
df_tob_03.tail()
# Out:
#         Trade Date  Trade Time  Trade Sequence Number Session Indicator  \
# 999995    20200312       85447               28048161                 E
# 999996    20200312       85447               28048162                 E
# 999997    20200312       85447               28048162                 E
# 999998    20200312       85447               28048166                 E
# 999999    20200312       85447               28048166                 E
#
#        Ticker Symbol FOI Indicator  Delivery Date  Trade Quantity  \
# 999995           CL              F           2004               9
# 999996           CL              F           2004              17
# 999997           CL              F           2004               9
# 999998           CL              F           2004               8
# 999999           CL              F           2004              17
#
#        Strike Price  Strike Price Decimal Locator  ...  Market Quote  \
# ...

# %%
df_tob_01 = pd.read_csv('../sports_betting_apis/temp_folder/df_clk20_tob_01.csv')
df_tob_01.tail()
# Out:
#         Trade Date  Trade Time  Trade Sequence Number Session Indicator  \
# 999995    20200312       33106               26264713                 E
# 999996    20200312       33106               26264713                 E
# 999997    20200312       33106               26264714                 E
# 999998    20200312       33106               26264714                 E
# 999999    20200312       33106               26264716                 E
#
#        Ticker Symbol FOI Indicator  Delivery Date  Trade Quantity  \
# 999995           CL              F           2004               9
# 999996           CL              F           2004              12
# 999997           CL              F           2004              11
# 999998           CL              F           2004               9
# 999999           CL              F           2004               6
#
#        Strike Price  Strike Price Decimal Locator  ...  Market Quote  \
# ...

# %%
23*60*60*1000/85000000
# Out:
# 0.9741176470588235
